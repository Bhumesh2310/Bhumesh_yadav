# %% [markdown]
# Project 1 - 911 Emergency Calls Analysis
# Dataset Link
# Report - Using Jupyter Notebook only.
# Idea - You need to share a full story about the dataset.
# Questions -
# How many different types of calls.
# Extract the date and time regarding the calls
# At what time of day/month I can expect which type of call.
# Visualize the percentage share of emergency type for each call.
#
# Project 2 - Employee Attrition Prediction, based on Employee previous records.
# Dataset provided in the email itself.
# Report - Using Jupyter Notebook only.
# Idea - You need to share a full story about the dataset, make a machine learning model, that predicts the attrition of the employee. The notebook should contain full analysis and machine learning prediction.
# Questions -
# Department wise performances.
# Top 3 Important Factors affecting employee performance.
# A trained model which can predict whether to hire employees.
# Recommendations to improve employee performance based on insights from analysis.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d=pd.read_csv('911.csv')

# %%
d.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
#How many different types of calls.

# %%
d.title.nunique()
# Out:
# 141

# %%
#Extract the date and time regarding the calls

# %%
x=pd.to_datetime(d.timeStamp)

# %%
import datetime as dt

# %%
d['Date']=x.dt.date

# %%
d['Time']=x.dt.time

# %%
d.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
#At what time of day/month I can expect which type of call.

# %%
d['month']=x.dt.month

# %%
d['dates']=x.dt.day

# %%
d.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
# At what time of day/month I can expect which type of call.

# %%
pd.DataFrame(d.groupby(['month','Time'])['title'].unique())
# Out:
#                                                             title
# month Time
# 1     00:00:01                              [Fire: GAS-ODOR/LEAK]
#       00:00:10                      [Traffic: VEHICLE ACCIDENT -]
#       00:00:13                             [EMS: SUBJECT IN PAIN]
#       00:00:17                                 [EMS: HEAD INJURY]
#       00:00:18                                    [EMS: OVERDOSE]
#       00:00:21                                 [Fire: FIRE ALARM]
#       00:00:32  [Fire: FIRE SPECIAL SERVICE, EMS: RESPIRATORY ...
#       00:00:35                                    [EMS: SEIZURES]
#       00:00:45                             [EMS: SUBJECT IN PAIN]
#       00:00:48                                  [EMS: CVA/STROKE]
#       00:00:58                                 [Fire: FIRE ALARM]
#       00:01:00          [Traffic: VEHICLE FIRE -, EMS: DIZZINESS]
#       00:01:09                      [Traffic: DISABLED VEHICLE -]
# ...

# %%
#Visualize the percentage share of emergency type for each call.

# %%
d["new_t"]=d["title"].apply(lambda x:str(x)[0:3])

# %%
d['new_t'].value_counts(1).plot(kind="bar")

# %%
data=pd.read_csv("Employee_Performance.csv")

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
#Department wise performances.

# %%
data.groupby("EmpDepartment")["PerformanceRating"].sum().plot(kind="bar")

# %%
data.isnull().sum()
# Out:
# EmpNumber                       0
# Age                             0
# Gender                          0
# EducationBackground             0
# MaritalStatus                   0
# EmpDepartment                   0
# EmpJobRole                      0
# BusinessTravelFrequency         0
# DistanceFromHome                0
# EmpEducationLevel               0
# EmpEnvironmentSatisfaction      0
# EmpHourlyRate                   0
# EmpJobInvolvement               0
# EmpJobLevel                     0
# EmpJobSatisfaction              0
# NumCompaniesWorked              0
# OverTime                        0
# EmpLastSalaryHikePercent        0
# EmpRelationshipSatisfaction     0
# TotalWorkExperienceInYears      0
# TrainingTimesLastYear           0
# EmpWorkLifeBalance              0
# ExperienceYearsAtThisCompany    0
# ExperienceYearsInCurrentRole    0
# YearsSinceLastPromotion         0
# YearsWithCurrManager            0
# Attrition                       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
# EmpNumber                       1200 non-null object
# Age                             1200 non-null int64
# Gender                          1200 non-null object
# EducationBackground             1200 non-null object
# MaritalStatus                   1200 non-null object
# EmpDepartment                   1200 non-null object
# EmpJobRole                      1200 non-null object
# BusinessTravelFrequency         1200 non-null object
# DistanceFromHome                1200 non-null int64
# EmpEducationLevel               1200 non-null int64
# EmpEnvironmentSatisfaction      1200 non-null int64
# EmpHourlyRate                   1200 non-null int64
# EmpJobInvolvement               1200 non-null int64
# EmpJobLevel                     1200 non-null int64
# EmpJobSatisfaction              1200 non-null int64
# NumCompaniesWorked              1200 non-null int64
# ...

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %% [markdown]
# #Deleting The some variable which are not important
# 1) EMP Number as this will help in predicting
# 2) Maritial status

# %%
data.drop(["EmpNumber","MaritalStatus"],axis=1,inplace=True)

# %%
data.drop("Gender",axis=1,inplace=True)

# %%
plt.figure(figsize=[10,10])
sns.heatmap(data.corr())

# %%
data.head()
# Out:
#    Age Gender EducationBackground    EmpDepartment       EmpJobRole  \
# 0   32   Male           Marketing            Sales  Sales Executive
# 1   47   Male           Marketing            Sales  Sales Executive
# 2   40   Male       Life Sciences            Sales  Sales Executive
# 3   41   Male     Human Resources  Human Resources          Manager
# 4   60   Male           Marketing            Sales  Sales Executive
#
#   BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0           Travel_Rarely                10                  3
# 1           Travel_Rarely                14                  4
# 2       Travel_Frequently                 5                  4
# 3           Travel_Rarely                10                  4
# 4           Travel_Rarely                16                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  ...  \
# 0                           4             55  ...
# 1                           4             42  ...
# ...

# %%
sns.countplot(data.EmpJobLevel,hue=data.Attrition)

# %%
# attrition rate is high where empjob level is 1

# %%
plt.xticks(rotation=90)
sns.countplot(data.EmpDepartment,hue=data.Attrition)

# %%
#Attrition rate is high in sales department.

# %%
sns.countplot(data.OverTime,hue=data.Attrition)

# %%
#there is big difference between the yes count and no cout but still we can say that the data is balanced

# %%
data.Attrition.value_counts(1)
# Out:
# No     0.851667
# Yes    0.148333
# Name: Attrition, dtype: float64

# %%
sns.boxplot(data.Age)

# %%
sns.boxplot(data.DistanceFromHome)

# %%
sns.boxplot(data.EmpHourlyRate)

# %%
sns.boxplot(data.TotalWorkExperienceInYears)

# %%
sns.boxplot(data.ExperienceYearsAtThisCompany)

# %%
sns.boxplot(data.ExperienceYearsInCurrentRole)

# %%
sns.boxplot(data.YearsSinceLastPromotion)

# %%
sns.pairplot(data)

# %%
data.head()
# Out:
#    Age EducationBackground    EmpDepartment       EmpJobRole  \
# 0   32           Marketing            Sales  Sales Executive
# 1   47           Marketing            Sales  Sales Executive
# 2   40       Life Sciences            Sales  Sales Executive
# 3   41     Human Resources  Human Resources          Manager
# 4   60           Marketing            Sales  Sales Executive
#
#   BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0           Travel_Rarely                10                  3
# 1           Travel_Rarely                14                  4
# 2       Travel_Frequently                 5                  4
# 3           Travel_Rarely                10                  4
# 4           Travel_Rarely                16                  4
#
#    EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  ...  \
# 0                           4             55                  3  ...
# 1                           4             42                  3  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data["new_EducationBackgroud"]=le.fit_transform(data.EducationBackground)

# %%
data["EmpDepartment"]=le.fit_transform(data.EmpDepartment)
data["EmpJobRole"]=le.fit_transform(data.EmpJobRole)
data["BusinessTravelFrequency"]=le.fit_transform(data.BusinessTravelFrequency)
data["OverTime"]=le.fit_transform(data.OverTime)
data["EducationBackground"]=le.fit_transform(data.EducationBackground)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

rfe = RFE(model,3)
rfe = rfe.fit(x,y)

print(rfe.support_)
print(rfe.ranking_)
print(x.columns)
# Out:
# [False False False False False False  True  True False False  True False
#  False False False False False False False False]
# [14 13  5 15 16  2  1  1  4  9  1  6 10  3 11  7  8 12 17 18]
# Index(['Age', 'EducationBackground', 'EmpDepartment',
#        'BusinessTravelFrequency', 'EmpEducationLevel',
#        'EmpEnvironmentSatisfaction', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpRelationshipSatisfaction', 'TotalWorkExperienceInYears',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'PerformanceRating', 'new_EducationBackgroud'],
#       dtype='object')

# %%
pd.DataFrame(rfe.ranking_,index=x.columns)
# Out:
#                                0
# Age                           14
# EducationBackground           13
# EmpDepartment                  5
# BusinessTravelFrequency       15
# EmpEducationLevel             16
# EmpEnvironmentSatisfaction     2
# EmpJobInvolvement              1
# EmpJobLevel                    1
# EmpJobSatisfaction             4
# NumCompaniesWorked             9
# OverTime                       1
# EmpRelationshipSatisfaction    6
# TotalWorkExperienceInYears    10
# EmpWorkLifeBalance             3
# ExperienceYearsAtThisCompany  11
# ExperienceYearsInCurrentRole   7
# YearsSinceLastPromotion        8
# YearsWithCurrManager          12
# PerformanceRating             17
# new_EducationBackgroud        18

# %%
# top 3 features is EmpJobInvolvement & OverTime & EmpJobLevel

# %%
data.drop(["EmpJobRole","DistanceFromHome","EmpHourlyRate","EmpHourlyRate","EmpLastSalaryHikePercent",
           "TrainingTimesLastYear","TrainingTimesLastYear"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Age  EducationBackground  EmpDepartment  BusinessTravelFrequency  \
# 0   32                    2              5                        2
# 1   47                    2              5                        2
# 2   40                    1              5                        1
# 3   41                    0              3                        2
# 4   60                    2              5                        2
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpJobInvolvement  \
# 0                  3                           4                  3
# 1                  4                           4                  3
# 2                  4                           4                  2
# 3                  4                           2                  2
# 4                  4                           1                  3
#
#    EmpJobLevel  EmpJobSatisfaction  NumCompaniesWorked  ...  \
# 0            2                   4                   1  ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x=data.drop("Attrition",axis=1)
y=data.Attrition

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=123)

# %%
scalled_train=sc.fit_transform(xtrain)
scalled_test=sc.fit_transform(xtest)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=100)
model=lr.fit(scalled_train,ytrain).predict(xtest)

# %%
print(lr.score(scalled_train,ytrain))
print(lr.score(scalled_test,ytest))
# Out:
# 0.8773809523809524
# 0.8722222222222222

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=30,criterion='entropy',max_depth=4)

# %%
model_rf=rf.fit(scalled_train,ytrain).predict(xtest)

# %%
print(rf.score(scalled_train,ytrain))
print(rf.score(scalled_test,ytest))
# Out:
# 0.8690476190476191
# 0.85

# %%
pd.Series(rf.feature_importances_,index=xtrain.columns).plot(kind="bar")
